# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('../data/intents.json').read()
intents = json.loads(data_file)
print(intents)
# Out:
# {'intents': [{'tag': 'greeting', 'patterns': ['Hi there', 'How are you', 'Is anyone there?', 'Hey', 'Hola', 'Hello', 'Good day'], 'responses': ['Hello, thanks for asking', 'Good to see you again', 'Hi there, how can I help?'], 'context': ['']}, {'tag': 'goodbye', 'patterns': ['Bye', 'See you later', 'Goodbye', 'Nice chatting to you, bye', 'Till next time'], 'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'], 'context': ['']}, {'tag': 'thanks', 'patterns': ['Thanks', 'Thank you', "That's helpful", 'Awesome, thanks', 'Thanks for helping me'], 'responses': ['Happy to help!', 'Any time!', 'My pleasure'], 'context': ['']}, {'tag': 'noanswer', 'patterns': [], 'responses': ["Sorry, can't understand you", 'Please give me more info', 'Not sure I understand'], 'context': ['']}, {'tag': 'options', 'patterns': ['How you could help me?', 'What you can do?', 'What help you provide?', 'How you can be helpful?', 'What support is offered'], 'responses': ['I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies', 'Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies'], 'context': ['']}, {'tag': 'adverse_drug', 'patterns': ['How to check Adverse drug reaction?', 'Open adverse drugs module', 'Give me a list of drugs causing adverse behavior', 'List all drugs suitable for patient with adverse reaction', 'Which drugs dont have adverse reaction?'], 'responses': ['Navigating to Adverse drug reaction module'], 'context': ['']}, {'tag': 'blood_pressure', 'patterns': ['Open blood pressure module', 'Task related to blood pressure', 'Blood pressure data entry', 'I want to log blood pressure results', 'Blood pressure data management'], 'responses': ['Navigating to Blood Pressure module'], 'context': ['']}, {'tag': 'blood_pressure_search', 'patterns': ['I want to search for blood pressure result history', 'Blood pressure for patient', 'Load patient blood pressure result', 'Show blood pressure results for patient', 'Find blood pressure results by ID'], 'responses': ['Please provide Patient ID', 'Patient ID?'], 'context': ['search_blood_pressure_by_patient_id']}, {'tag': 'search_blood_pressure_by_patient_id', 'patterns': [], 'responses': ['Loading Blood pressure result for Patient'], 'context': ['']}, {'tag': 'pharmacy_search', 'patterns': ['Find me a pharmacy', 'Find pharmacy', 'List of pharmacies nearby', 'Locate pharmacy', 'Search pharmacy'], 'responses': ['Please provide pharmacy name'], 'context': ['search_pharmacy_by_name']}, {'tag': 'search_pharmacy_by_name', 'patterns': [], 'responses': ['Loading pharmacy details'], 'context': ['']}, {'tag': 'hospital_search', 'patterns': ['Lookup for hospital', 'Searching for hospital to transfer patient', 'I want to search hospital data', 'Hospital lookup for patient', 'Looking up hospital details'], 'responses': ['Please provide hospital name or location'], 'context': ['search_hospital_by_params']}, {'tag': 'search_hospital_by_params', 'patterns': [], 'responses': ['Please provide hospital type'], 'context': ['search_hospital_by_type']}, {'tag': 'search_hospital_by_type', 'patterns': [], 'responses': ['Loading hospital details'], 'context': ['']}]}

# %% [markdown]
# #### Preprocess data

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('../models/words.pkl','wb'))
pickle.dump(classes,open('../models/classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('../models/chatbot_model.h5', hist)

print("model created")
# Out:
# 2022-02-05 02:38:50.634025: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.2091 - accuracy: 0.1064
# Epoch 2/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.1098 - accuracy: 0.2979
# Epoch 3/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9232 - accuracy: 0.4468
# Epoch 4/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9002 - accuracy: 0.4043
# Epoch 5/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8394 - accuracy: 0.3617
# Epoch 6/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7298 - accuracy: 0.4468
# Epoch 7/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6269 - accuracy: 0.5106
# Epoch 8/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4822 - accuracy: 0.5532
# Epoch 9/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3338 - accuracy: 0.6170
# Epoch 10/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2434 - accuracy: 0.6170
# Epoch 11/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0616 - accuracy: 0.6596
# Epoch 12/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9983 - accuracy: 0.6596
# Epoch 13/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7913 - accuracy: 0.8085
# Epoch 14/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9286 - accuracy: 0.7021
# Epoch 15/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7478 - accuracy: 0.8085
# Epoch 16/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6314 - accuracy: 0.7660
# Epoch 17/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6826 - accuracy: 0.7660
# Epoch 18/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5360 - accuracy: 0.8723
# Epoch 19/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5382 - accuracy: 0.8511
# Epoch 20/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4364 - accuracy: 0.9362
# Epoch 21/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4121 - accuracy: 0.9149
# Epoch 22/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3321 - accuracy: 0.9149
# Epoch 23/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3525 - accuracy: 0.8723
# Epoch 24/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4588 - accuracy: 0.8723
# Epoch 25/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3002 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3087 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3023 - accuracy: 0.8936
# Epoch 29/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2235 - accuracy: 0.9574
# Epoch 30/200
# 10/10 [==============================] - 0s 985us/step - loss: 0.2931 - accuracy: 0.9362
# Epoch 31/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2857 - accuracy: 0.9149
# Epoch 32/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3686 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 999us/step - loss: 0.3319 - accuracy: 0.9362
# Epoch 34/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2862 - accuracy: 0.9362
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2192 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2068 - accuracy: 0.9787
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1967 - accuracy: 0.9787
# Epoch 38/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3417 - accuracy: 0.8936
# Epoch 39/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1157 - accuracy: 0.9787
# Epoch 40/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0896 - accuracy: 1.0000
# Epoch 41/200
# 10/10 [==============================] - 0s 975us/step - loss: 0.0750 - accuracy: 1.0000
# Epoch 42/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1571 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1332 - accuracy: 0.9787
# Epoch 44/200
# 10/10 [==============================] - 0s 944us/step - loss: 0.0917 - accuracy: 1.0000
# Epoch 45/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1213 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1396 - accuracy: 0.9574
# Epoch 47/200
# 10/10 [==============================] - 0s 962us/step - loss: 0.0917 - accuracy: 0.9787
# Epoch 48/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0787 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 0.9787
# Epoch 50/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1332 - accuracy: 0.9574
# Epoch 51/200
# 10/10 [==============================] - 0s 928us/step - loss: 0.1411 - accuracy: 0.9574
# Epoch 52/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0703 - accuracy: 0.9787
# Epoch 53/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0915 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1117 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 986us/step - loss: 0.1033 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0366 - accuracy: 0.9787
# Epoch 57/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1315 - accuracy: 0.9787
# Epoch 58/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0990 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0741 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0692 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0739 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9787
# Epoch 64/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1076 - accuracy: 0.9574
# Epoch 66/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 979us/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1136 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1010 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0636 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0999 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0623 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0655 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0839 - accuracy: 0.9787
# Epoch 83/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0854 - accuracy: 0.9574
# Epoch 85/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9787
# Epoch 89/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0879 - accuracy: 0.9574
# Epoch 92/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0668 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0277 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1162 - accuracy: 0.9574
# Epoch 97/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0818 - accuracy: 0.9574
# Epoch 98/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0840 - accuracy: 0.9574
# Epoch 100/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1408 - accuracy: 0.9574
# Epoch 103/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0352 - accuracy: 0.9787
# Epoch 105/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0694 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1038 - accuracy: 0.9574
# Epoch 108/200
# 10/10 [==============================] - 0s 966us/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 959us/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9787
# Epoch 120/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0803 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0527 - accuracy: 0.9787
# Epoch 124/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0749 - accuracy: 0.9574
# Epoch 125/200
# 10/10 [==============================] - 0s 975us/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 0.9787
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 947us/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0904 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0354 - accuracy: 0.9787
# Epoch 146/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9787
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0260 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0484 - accuracy: 0.9787
# Epoch 170/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0871 - accuracy: 0.9362
# Epoch 172/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0402 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0531 - accuracy: 0.9787
# Epoch 179/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1073 - accuracy: 0.9574
# Epoch 182/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 955us/step - loss: 0.0322 - accuracy: 0.9787
# Epoch 185/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0520 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0330 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 967us/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0632 - accuracy: 0.9787
# Epoch 192/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 936us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 1.0000
# model created

# %%
# %run chat.ipynb

# %%
# %run gui.ipynb
# Out:
# Collecting tk
#   Using cached tk-0.1.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: tk
# Successfully installed tk-0.1.0
# Note: you may need to restart the kernel to use updated packages.
